# %% [markdown]
# # Scikit-learn for Linear Regression
# <br>

# %%
import numpy as np 
import scipy.stats as ss
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
n = 500
beta_0 = 5
beta_1 = 2
beta_2 = -1
np.random.seed(1)

x_1 = 10 * ss.uniform.rvs(size = n)
x_2 = 10 * ss.uniform.rvs(size = n)

y = beta_0 + beta_1 * x_1 + beta_2 * x_2 + ss.norm.rvs(loc=0, scale=1, size=n)

# %%
X = np.stack([x_1, x_2], axis = 1)
X
# Out:
# array([[4.17022005e+00, 8.74822096e-01],
#        [7.20324493e+00, 2.27309736e+00],
#        [1.14374817e-03, 3.14376616e+00],
#        [3.02332573e+00, 1.74765876e+00],
#        [1.46755891e+00, 6.07094162e+00],
#        [9.23385948e-01, 4.13586415e+00],
#        [1.86260211e+00, 8.16351512e+00],
#        [3.45560727e+00, 1.85130398e+00],
#        [3.96767474e+00, 7.01876530e+00],
#        [5.38816734e+00, 2.40355625e+00],
#        [4.19194514e+00, 5.74219089e+00],
#        [6.85219500e+00, 3.48987597e+00],
#        [2.04452250e+00, 5.69643995e-01],
#        [8.78117436e+00, 2.28813671e+00],
#        [2.73875932e-01, 6.64102555e+00],
#        [6.70467510e+00, 4.97250093e+00],
#        [4.17304802e+00, 5.19015984e+00],
#        [5.58689828e+00, 1.74720150e+00],
#        [1.40386939e+00, 5.70715852e+00],
#        [1.98101489e+00, 9.96753425e+00],
#        [8.00744569e+00, 8.16835109e+00],
#        [9.68261576e+00, 5.94372624e+00],
#        [3.13424178e+00, 9.75989068e+00],
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
#switch between qt and inline to see interactive 3d or static plots
#matplotlib qt
# %matplotlib inline 

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], y, c=y)
ax.set_xlabel("x_1")
ax.set_ylabel("x_2")
ax.set_zlabel("y")
# Out:
# Text(0.5, 0, 'y')

# %%
lm = LinearRegression(fit_intercept = True)
lm.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.intercept_
# Out:
# 5.154077763777246

# %%
lm.coef_    #first element gives value of beta_1 and the second element gives the value of beta_2
# Out:
# array([ 1.9999379 , -1.02026449])

# %%
X_0 = np.array([2, 4])    #predict value of the outcome for some vaue of X

lm.predict(X_0.reshape(1, -1))
# Out:
# array([5.07289561])

# %%
lm.score(X, y)
# Out:
# 0.9798997316600129

# %% [markdown]
# ## Assessing Model Accuracy:
# <br>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.5, random_state = 1)    #split data into training and test sets

# %%
lm = LinearRegression(fit_intercept=True)
lm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.score(X_test, y_test)    #To check how well the model performs with test data
# Out:
# 0.9794930834681773
